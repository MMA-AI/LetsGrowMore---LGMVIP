# %% [markdown]
# ## 4) Image to Pencil Sketch with Python || Task 4 || August 2021 || Data Science Internship

# %% [markdown]
# ### Importing Libraries

# %% [markdown]
# The only library we need for converting an image into a pencil sketch with Python is an OpenCV library in Python. It can be used by using the pip command; pip install opencv-python. But it is not imported by the same name. Let’s import it to get started with the task:

# %%
from IPython import display
from IPython.display import Image

# %%
Image(url="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/A_chital_stag_1.JPG/1280px-A_chital_stag_1.JPG", width=874, height=652)
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/A_chital_stag_1.JPG/1280px-A_chital_stag_1.JPG" width="874" height="652"/>

# %% [markdown]
# Let's code:

# %%
# !pip install opencv-python

# %%
# Import the library
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Get the Image location and the image file name
imagepath = "C:/Users/mmuqt/Downloads/A_chital_deer.jpg"
filename = 'A_chital_deer.jpg'

# %%
#type of imagepath
type(imagepath)
# Out:
# str

# %%
# Read in the image
img = cv2.imread(imagepath)

# %%
# convert the image to grey scale
grey_filter = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#wait for user to press any keys
#(this is necessary to avoid python kernel form crashing)
cv2.waitKey(0)
# Out:
# -1

# %%
#Invert the image
invert = cv2.bitwise_not(grey_filter)

# %%
#Blur the image by gussian function
blur = cv2.GaussianBlur(invert, (21,21),0)

# %%
#using bitwise_not function to inevrt the image
invertedblur = cv2.bitwise_not(blur)

# %%
#sketch filter function
sketch_filter = cv2.divide(grey_filter, invertedblur, scale=256.0)

# %%
#Sketch filter output image
cv2.imwrite("output.png", sketch_filter)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#original image and the pencil sketch
invertedblur = 255 - blur
sketch_filter = cv2.divide(grey_filter, invertedblur, scale=256.0)
cv2.imshow("output.png", sketch_filter)
cv2.waitKey(0)
# Out:
# -1

# %%
# show the image
cv2.imshow("original image", img)
cv2.imshow("sketch_filter", sketch_filter)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![A_chital_deer.jpg](attachment:A_chital_deer.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)
